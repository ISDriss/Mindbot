# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#muselsl stream
#muselsl view --version2

recording = pd.read_csv("EEG_recording_2024-10-24-14.53.10.csv", sep = ',')

# %%
recording.head
# Out:
# <bound method NDFrame.head of         timestamps      TP9     AF7      AF8     TP10  Right AUX
# 0     1.729782e+09   73.730 -20.508 -122.070   22.949        0.0
# 1     1.729782e+09   26.855 -23.438 -244.141  -49.316        0.0
# 2     1.729782e+09  127.441 -19.043 -252.441    3.418        0.0
# 3     1.729782e+09  230.469 -19.531   -7.324  102.051        0.0
# 4     1.729782e+09  196.777 -22.461  123.047  123.047        0.0
# ...            ...      ...     ...      ...      ...        ...
# 1291  1.729782e+09 -108.887 -66.895 -808.105 -134.277        0.0
# 1292  1.729782e+09  -66.895 -22.949 -840.332 -140.625        0.0
# 1293  1.729782e+09   64.453 -30.762 -839.355  -41.992        0.0
# 1294  1.729782e+09  143.555 -62.012 -782.715   37.598        0.0
# 1295  1.729782e+09   97.168 -31.738 -807.129   42.480        0.0
#
# [1296 rows x 6 columns]>

# %%
plt.plot(recording['timestamps'].to_list(), recording['TP9'].tolist())

# %%
plt.plot(recording['timestamps'].to_list(), recording['AF7'].tolist())

# %%
plt.plot(recording['timestamps'].to_list(), recording['AF8'].tolist())

# %%
plt.plot(recording['timestamps'].to_list(), recording['TP10'].tolist())
